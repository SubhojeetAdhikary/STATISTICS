# %% [markdown]
# ## **Question 1: A die is rolled. What is the probability of getting:**
#
# (a) An even number
#
# (b) A number greater than 4

# %% [markdown]
# ## **Ans-**
#
# A die is rolled.
#
# Total outcomes = 6 = {1, 2, 3, 4, 5, 6}
#
# (a) Probability of getting an even number
#
# Even numbers = {2, 4, 6}
#
# P(Even)= 3/6
#
#
#        = 1/2
#        =0.5
#
# ##### **Answer:** 1/2 (0.5)
#
# (b) Probability of getting a number greater than 4
#
# Numbers greater than 4 = {5, 6}
#
# P(>4)= 2/6
# 	​
#
#      = 1/3
# 	​ ≈0.333
#
# ##### **Answer:** 1/3 (0.333)

# %% [markdown]
# ## **Question 2: In a class of 50 students:**
#
# 20 like Mathematics (M)
#
# 15 like Science (S)
#
# 5 like both subjects
#
# What is the probability that a student chosen at random likes Mathematics or Science?

# %% [markdown]
# ## **Ans-**
#
# Given:
#
# Total students = 50
#
# Like Mathematics (M) = 20
#
# Like Science (S) = 15
#
# Like both subjects = 5
#
# Using the Addition Rule:
#
#     P(M ∪ S) = (M + S - M ∩ S) / Total Students
#
#     P(M ∪ S) = (20 + 15 - 5) / 50
#
#     P(M ∪ S) = 30 / 50
#
#     P(M ∪ S) = 0.6
#
# Answer: 0.6 or 60%

# %% [markdown]
# ## **Question 3: A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability that the next ball is also red (without replacement)?**

# %% [markdown]
# ## **Ans-**
#
# Given:
#
# 3 Red Balls
# 2 Blue Balls
#
# The first ball drawn is red.
#
# Remaining balls:
#
# 2 Red
# 2 Blue
#
# Total remaining balls = 4
#
# P(Next Ball is Red)
#
#     = 2/4
#     = 1/2
#
# Answer: 0.5

# %% [markdown]
# ## **Question 4: The population of a school is divided into 60% boys and 40% girls. If you want equal representation of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling? Why?**

# %% [markdown]
# ## **Ans-**
#
# Population: 60% Boys 40% Girls
#
# Requirement: Equal representation of both genders.
#
# Answer: **Stratified Sampling**
#
# ##### **Reason:**
#
# The population is divided into groups (Boys and Girls), and samples are selected from each group separately to ensure proper representation from both groups.

# %% [markdown]
# ## **Question 5: The average height of 1000 students = 160 cm. A sample of 100 students shows an average height = 158 cm. Find the sampling error.**

# %% [markdown]
# ## **Ans-**
#
# Given:
#
# Population Mean = 160 cm
#
# Sample Mean = 158 cm
#
# Formula:
#
# Sampling Error = Sample Mean - Population Mean
#
# Sampling Error = 158 - 160
#
# Sampling Error = -2 cm
#
# Interpretation:
#
# The sample mean is 2 cm lower than the population mean.
#
# Answer: -2 cm

# %% [markdown]
# ## **Question 6: The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what is the standard error of the mean (SEM)?**

# %% [markdown]
# ## **Ans-**
#
# Given:
#
# Population Standard Deviation = ₹5,000
#
# Sample Size (n) = 100
#
# Formula:
#
# SEM = σ / √n
#
# SEM = 5000 / √100
#
# SEM = 5000 / 10
#
# SEM = 500
#
# Answer: ₹500

# %% [markdown]
# ## **Question 7: In a group of 100 students:**
#
# - 40 like Cricket (C)
#
# - 30 like Football (F)
#
# - 10 like both Cricket and Football
#
# #### **Find the probability that a student likes at least one sport**

# %% [markdown]
# ## **Ans-**
# Given:
#
# Total Students = 100
#
# Like Cricket (C) = 40
#
# Like Football (F) = 30
#
# Like Both Sports = 10
#
# Students who like at least one sport:
#
# C ∪ F = C + F - (C ∩ F)
#
# C ∪ F = 40 + 30 - 10
#
# C ∪ F = 60
#
# Probability:
#
# P(C ∪ F) = 60 / 100
#
# P(C ∪ F) = 0.6
#
# Interpretation:
#
# 60% of students like Cricket, Football, or both.
#
# Answer: 0.6 or 60%

# %% [markdown]
# ## **Question 8: From a deck of 52 cards, two cards are drawn without replacement. What is the probability that both are Aces?**

# %% [markdown]
# ## **Ans-**
#
# Given:
#
# Total Cards = 52
#
# Total Aces = 4
#
# Probability of first Ace:
#
# P(First Ace)
#
#     = 4/52
#
# Probability of second Ace:
#
# P(Second Ace)
#
#     = 3/51
#
# P(Both Aces)
#
#     = (4/52) × (3/51)
#
#     = 12/2652
#
#     = 1/221
#
#     ≈ 0.00452
#
# Answer: 0.00452 or 0.452%

# %% [markdown]
# ## **Question 9: A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the probability that all are non-defective?**

# %% [markdown]
# ## **Ans-**
#
# Given:
#
# Defective Rate = 2%
#
# Probability of a Non-Defective Bulb:
#
# P(Non-Defective) = 1 - 0.02
#
# P(Non-Defective) = 0.98
#
# For 5 bulbs:
#
# P(All Non-Defective) = (0.98)^5
#
# P(All Non-Defective) = 0.9039
#
# Answer: 0.9039 or 90.39%

# %% [markdown]
# ## **Question 10: Differentiate between discrete and continuous random variables with examples.**

# %% [markdown]
# ## **Ans-**
#
# #### **Difference Between Discrete and Continuous Random Variables**
#
# **Discrete Random Variable:**
# - Takes countable values.
# - Obtained through counting.
# - Examples:
#   * Number of students in a class
#   * Number of cars in a parking lot
#   * Number of heads in coin tosses
#
# **Continuous Random Variable:**
# - Takes any value within a range.
# - Obtained through measurement.
# - Examples:
#   * Height
#   * Weight
#   * Temperature
#   * Salary
#
# Conclusion:
#
# Discrete variables are countable, whereas continuous variables can take any value within a given interval.
